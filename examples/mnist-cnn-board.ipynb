# %% [markdown]
# # MNIST CNN Board Example
# Adapted from [TensorFlow: Deep MNIST for Experts](https://www.tensorflow.org/tutorials/mnist/pros/index.html).
#
# Demonstrates the usage of the *tensortools/board* module.

# %%
import os
import sys

# add path to libraries for ipython
sys.path.append(os.path.expanduser("~/libs"))

import time
from datetime import datetime
import numpy as npvariable_scope
import tensorflow as tf
import tensortools as tt

# %%
BATCH_SIZE = 50
MAX_STEPS = 2000
DROPOUT = 0.5
LEARNING_RATE = 1e-4
REG = 5e-4
TRAIN_DIR = 'train'

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
def inference(x, dropout_keep_prob):
    x_image = tf.reshape(x, [-1,28,28,1])

    # Conv1
    conv1 = tt.network.conv2d("Conv1", x_image,
                              32, 5, 5, 1, 1,
                              weight_init=0.01, 
                              bias=0.1,
                              regularizer=tf.contrib.layers.l2_regularizer(REG),
                              activation=tf.nn.relu)
    tt.board.activation_summary(conv1, True, scope="Conv1")
    h_pool1 = tt.network.max_pool2d(conv1, 2, 2, 2, 2)

    # Conv2
    conv2 = tt.network.conv2d("Conv2", h_pool1,
                              64, 5, 5, 1, 1,
                              weight_init=0.01, 
                              bias=0.1,
                              regularizer=tf.contrib.layers.l2_regularizer(REG))
    h_conv2 = tt.network.lrelu(conv2, 0.2)
    tt.board.activation_summary(h_conv2, scope="Conv2")
    h_pool2 = tt.network.max_pool2d(h_conv2, 2, 2, 2, 2)
    
    # Conv3
    conv3 = tt.network.conv2d("Conv3", h_pool2,
                              64, 5, 5, 1, 1,
                              weight_init=0.01, 
                              bias=0.1,
                              regularizer=tf.contrib.layers.l2_regularizer(REG))
    h_conv3 = tf.nn.relu(conv3, name="ReLu")
    tt.board.activation_summary(h_conv3, scope="Conv3")

    # FC
    h_pool2_flat = tf.reshape(h_conv3, [-1, 7*7*64])
    fc1 = tt.network.fc("FC", h_pool2_flat, 1024,
                          weight_init=tf.contrib.layers.xavier_initializer(), 
                          bias=0.1,
                          regularizer=tf.contrib.layers.l2_regularizer(REG))
    h_fc1 = tf.nn.relu(fc1, name="ReLu")
    tt.board.activation_summary(h_fc1, scope="FC")

    h_fc1_drop = tf.nn.dropout(h_fc1, dropout_keep_prob)

    # Output
    y_conv=tf.nn.softmax(tt.network.fc("Output", h_fc1_drop, 10,
                                       weight_init=tf.contrib.layers.xavier_initializer(),
                                       regularizer=tf.contrib.layers.l2_regularizer(REG),
                                       bias=0.1))
    return y_conv

# %%
def train(output, label, global_step):
    with tf.name_scope("Train"):
        cross_entropy = tf.reduce_mean(-tf.reduce_sum(label * tf.log(output), reduction_indices=[1]), name="cross_entropy")
        
        reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
        print("{} regularization losses in total.".format(len(reg_losses)))
        total_loss = tf.add(cross_entropy, tf.add_n(reg_losses), name="total_loss")
        
        # Generate moving averages of all losses and associated summaries
        cost_averages_op = tt.board.loss_summary([total_loss, cross_entropy] + reg_losses)
        
        # Compute gradients
        with tf.control_dependencies([cost_averages_op]):
            opt = tf.train.AdamOptimizer(LEARNING_RATE)
            grads = opt.compute_gradients(total_loss)
        
        # Apply gradients
        apply_gradient_op = opt.apply_gradients(grads, global_step=global_step)
        
        tt.board.variables_histogram_summary()
        
        # Add histograms for gradients
        tt.board.gradients_histogram_summary(grads)
        
        with tf.control_dependencies([apply_gradient_op]):
            train_op = tf.no_op(name='train')
        
    return train_op

# %%
def accuracy(output, label):
    with tf.name_scope("Accuracy"):
        correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(label,1))
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    return accuracy

# %%
with tf.Graph().as_default():
    global_step = tf.Variable(0, trainable=False)
    
    x = tf.placeholder(tf.float32, [None, 784], "X")
    y_ = tf.placeholder(tf.float32, [None, 10], "Y_")
    keep_prob = tf.placeholder(tf.float32, name="KeepProb")
    
    output = inference(x, keep_prob)
    train_op = train(output, y_, global_step)
    accuracy_op = accuracy(output, y_)
    
    summary_op = tf.merge_all_summaries()
    
    gpu_options = tf.GPUOptions(
        per_process_gpu_memory_fraction=0.5,
        allow_growth=True)
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options)) as sess:
        sess.run(tf.initialize_all_variables())

        # Visualize graph
        tt.visualization.show_graph(sess.graph_def)
        
        # Create a TensorBoard Writer of all summaries
        summary_writer = tf.train.SummaryWriter(TRAIN_DIR, sess.graph)

        for step in range(MAX_STEPS):
            
            start_time = time.time()
            
            batch = mnist.train.next_batch(BATCH_SIZE)

            sess.run(train_op, feed_dict={x: batch[0],
                                          y_: batch[1],
                                          keep_prob: DROPOUT})
            
            duration = time.time() - start_time
            
            if step % 10 == 0:
                train_accuracy = sess.run(accuracy_op,
                                          feed_dict={x:batch[0],
                                                     y_: batch[1],
                                                     keep_prob: 1.0})
                
                num_examples_per_step = BATCH_SIZE
                examples_per_sec = num_examples_per_step / duration
                sec_per_batch = float(duration)

                format_str = ('%s: step %d, acc = %.2f (%.1f examples/sec; %.3f sec/batch)')
                print (format_str % (datetime.now().time(), step, train_accuracy,
                                     examples_per_sec, sec_per_batch))
                
            if step % 100 == 0:
                summary_str = sess.run(summary_op,
                                      feed_dict={x:batch[0],
                                                 y_: batch[1],
                                                 keep_prob: 1.0})
                summary_writer.add_summary(summary_str, step)
                # flush data because there can be problems writing the data
                summary_writer.flush() 
                
        print("Test accuracy: %g" % sess.run(accuracy_op, 
                                             feed_dict={x: mnist.test.images[:1000],
                                                        y_: mnist.test.labels[:1000],
                                                        keep_prob: 1.0}))
        
print("DONE! All outputs have been written to: {0}".format(TRAIN_DIR))
# Out:
# 5 regularization losses in total.
#         <iframe seamless style="width:100%;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.781384833606&quot;).pbtxt = 'node {\n  name: &quot;Variable/initial_value&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n        }\n        int_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Variable&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Variable/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Variable&quot;\n  input: &quot;Variable/initial_value&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Variable&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Variable/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Variable&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Variable&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;X&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Y_&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;KeepProb&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Reshape/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\377\\377\\377\\377\\034\\000\\000\\000\\034\\000\\000\\000\\001\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Reshape&quot;\n  op: &quot;Reshape&quot;\n  input: &quot;X&quot;\n  input: &quot;Reshape/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Conv1/W&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 5\n        }\n        dim {\n          size: 5\n        }\n        dim {\n          size: 1\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Conv1/W/Initializer/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Conv1/W&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key:  ...
# 15:04:19.382840: step 0, acc = 0.22 (1730.0 examples/sec; 0.029 sec/batch)
# 15:04:19.762172: step 10, acc = 0.08 (4794.4 examples/sec; 0.010 sec/batch)
# 15:04:19.850322: step 20, acc = 0.06 (6012.5 examples/sec; 0.008 sec/batch)
# 15:04:19.937369: step 30, acc = 0.08 (5739.2 examples/sec; 0.009 sec/batch)
# 15:04:20.025603: step 40, acc = 0.16 (5735.9 examples/sec; 0.009 sec/batch)
# 15:04:20.112606: step 50, acc = 0.04 (5378.1 examples/sec; 0.009 sec/batch)
# 15:04:20.198531: step 60, acc = 0.12 (6275.1 examples/sec; 0.008 sec/batch)
# 15:04:20.285779: step 70, acc = 0.10 (5775.1 examples/sec; 0.009 sec/batch)
# 15:04:20.372542: step 80, acc = 0.14 (5962.2 examples/sec; 0.008 sec/batch)
# 15:04:20.461278: step 90, acc = 0.08 (6000.3 examples/sec; 0.008 sec/batch)
# 15:04:20.548877: step 100, acc = 0.10 (5823.5 examples/sec; 0.009 sec/batch)
# 15:04:20.800980: step 110, acc = 0.18 (5696.6 examples/sec; 0.009 sec/batch)
# 15:04:20.891005: step 120, acc = 0.12 (6049.6 examples/sec; 0.008 sec/batch)
# 15:04:20.980581: step 130, acc = 0.12 (4466.3 examples/sec; 0.011 sec/batch)
# 15:04:21.074563: step 140, acc = 0.22 (4995.0 examples/sec; 0.010 sec/batch)
# 15:04:21.163544: step 150, acc = 0.32 (6095.3 examples/sec; 0.008 sec/batch)
# 15:04:21.248483: step 160, acc = 0.48 (6205.7 examples/sec; 0.008 sec/batch)
# 15:04:21.332091: step 170, acc = 0.56 (6281.3 examples/sec; 0.008 sec/batch)
# 15:04:21.414551: step 180, acc = 0.62 (6219.7 examples/sec; 0.008 sec/batch)
# 15:04:21.503246: step 190, acc = 0.70 (6073.9 examples/sec; 0.008 sec/batch)
# 15:04:21.602331: step 200, acc = 0.80 (5454.4 examples/sec; 0.009 sec/batch)
# 15:04:21.960956: step 210, acc = 0.78 (5689.7 examples/sec; 0.009 sec/batch)
# 15:04:22.054702: step 220, acc = 0.72 (5320.3 examples/sec; 0.009 sec/batch)
# 15:04:22.150352: step 230, acc = 0.76 (5466.9 examples/sec; 0.009 sec/batch)
# 15:04:22.243337: step 240, acc = 0.90 (5540.3 examples/sec; 0.009 sec/batch)
# 15:04:22.339779: step 250, acc = 0.82 (5345.9 examples/sec; 0.009 sec/batch)
# 15:04:22.434504: step 260, acc = 0.88 (5444.9 examples/sec; 0.009 sec/batch)
# 15:04:22.533006: step 270, acc = 0.84 (5305.1 examples/sec; 0.009 sec/batch)
# 15:04:22.625741: step 280, acc = 0.72 (5527.4 examples/sec; 0.009 sec/batch)
# 15:04:22.713774: step 290, acc = 0.82 (5913.6 examples/sec; 0.008 sec/batch)
# 15:04:22.803734: step 300, acc = 0.82 (5425.3 examples/sec; 0.009 sec/batch)
# 15:04:23.149374: step 310, acc = 0.88 (5757.1 examples/sec; 0.009 sec/batch)
# 15:04:23.243055: step 320, acc = 0.92 (5098.0 examples/sec; 0.010 sec/batch)
# 15:04:23.339348: step 330, acc = 0.78 (5647.8 examples/sec; 0.009 sec/batch)
# 15:04:23.429469: step 340, acc = 0.88 (5778.4 examples/sec; 0.009 sec/batch)
# 15:04:23.521810: step 350, acc = 0.86 (5867.1 examples/sec; 0.009 sec/batch)
# 15:04:23.611350: step 360, acc = 0.88 (5947.5 examples/sec; 0.008 sec/batch)
# 15:04:23.700162: step 370, acc = 0.86 (5988.1 examples/sec; 0.008 sec/batch)
# 15:04:23.791625: step 380, acc = 0.92 (5379.8 examples/sec; 0.009 sec/batch)
# 15:04:23.885100: step 390, acc = 0.90 (5567.3 examples/sec; 0.009 sec/batch)
# 15:04:24.095159: step 400, acc = 0.88 (414.2 examples/sec; 0.121 sec/batch)
# 15:04:24.493532: step 410, acc = 0.84 (5128.8 examples/sec; 0.010 sec/batch)
# 15:04:24.583733: step 420, acc = 0.86 (5735.3 examples/sec; 0.009 sec/batch)
# 15:04:24.668826: step 430, acc = 0.96 (6194.3 examples/sec; 0.008 sec/batch)
# 15:04:24.753667: step 440, acc = 0.90 (6154.7 examples/sec; 0.008 sec/batch)
# 15:04:24.839097: step 450, acc = 0.90 (5987.9 examples/sec; 0.008 sec/batch)
# 15:04:24.925919: step 460, acc = 0.96 (6118.4 examples/sec; 0.008 sec/batch)
# 15:04:25.012562: step 470, acc = 0.94 (5940.3 examples/sec; 0.008 sec/batch)
# 15:04:25.107999: step 480, acc = 0.92 (5397.8 examples/sec; 0.009 sec/batch)
# 15:04:25.195096: step 490, acc = 0.96 (6122.2 examples/sec; 0.008 sec/batch)
# 15:04:25.284848: step 500, acc = 0.86 (5462.0 examples/sec; 0.009 sec/batch)
# 15:04:25.653491: step 510, acc = 0.94 (5152.5 examples/sec; 0.010 sec/batch)
# 15:04:25.747788: step 520, acc = 0.94 (5592.3 examples/sec; 0.009 sec/batch)
# 15:04:25.836529: step 530, acc = 0.88 (5875.5 examples/sec; 0.009 sec/batch)
# 15:04:25.931591: step 540, acc = 0.94 (4975.2 examples/sec; 0.010 sec/batch)
# 15:04:26.026601: step 550, acc = 0.92 (5559.9 examples/sec; 0.009 sec/batch)
# 15:04:26.121776: step 560, acc = 0.90 (5304.5 examples/sec; 0.009 sec/batch)
# 15:04:26.218068: step 570, acc = 0.98 (5931.2 examples/sec; 0.008 sec/batch)
# 15:04:26.308902: step 580, acc = 0.92 (5450.1 examples/sec; 0.009 sec/batch)
# 15:04:26.404798: step 590, acc = 0.96 (5189.3 examples/sec; 0.010 sec/batch)
# 15:04:26.505647: step 600, acc = 0.94 (5203.5 examples/sec; 0.010 sec/batch)
# 15:04:26.909902: step 610, acc = 1.00 (5505.5 examples/sec; 0.009 sec/batch)
# 15:04:27.006012: step 620, acc = 0.98 (4911.6 examples/sec; 0.010 sec/batch)
# 15:04:27.096169: step 630, acc = 0.96 (5891.4 examples/sec; 0.008 sec/batch)
# 15:04:27.190477: step 640, acc = 0.92 (5525.5 examples/sec; 0.009 sec/batch)
# 15:04:27.288001: step 650, acc = 0.98 (4436.6 examples/sec; 0.011 sec/batch)
# 15:04:27.376102: step 660, acc = 0.94 (5998.0 examples/sec; 0.008 sec/batch)
# 15:04:27.465699: step 670, acc = 0.92 (5794.5 examples/sec; 0.009 sec/batch)
# 15:04:27.555174: step 680, acc = 0.98 (5620.4 examples/sec; 0.009 sec/batch)
# 15:04:27.644972: step 690, acc = 0.96 (5562.3 examples/sec; 0.009 sec/batch)
# 15:04:27.735240: step 700, acc = 0.90 (5856.8 examples/sec; 0.009 sec/batch)
# 15:04:28.147361: step 710, acc = 0.94 (5619.4 examples/sec; 0.009 sec/batch)
# 15:04:28.239855: step 720, acc = 1.00 (5578.6 examples/sec; 0.009 sec/batch)
# 15:04:28.334743: step 730, acc = 0.98 (4720.1 examples/sec; 0.011 sec/batch)
# 15:04:28.421835: step 740, acc = 1.00 (6127.4 examples/sec; 0.008 sec/batch)
# 15:04:28.504581: step 750, acc = 0.98 (6443.3 examples/sec; 0.008 sec/batch)
# 15:04:28.581905: step 760, acc = 0.90 (6676.5 examples/sec; 0.007 sec/batch)
# 15:04:28.662243: step 770, acc = 1.00 (6248.4 examples/sec; 0.008 sec/batch)
# 15:04:28.748067: step 780, acc = 0.98 (6008.2 examples/sec; 0.008 sec/batch)
# 15:04:28.836818: step 790, acc = 0.98 (6078.3 examples/sec; 0.008 sec/batch)
# 15:04:28.926878: step 800, acc = 0.94 (5628.1 examples/sec; 0.009 sec/batch)
# 15:04:29.323030: step 810, acc = 0.96 (5140.8 examples/sec; 0.010 sec/batch)
# 15:04:29.416826: step 820, acc = 0.98 (5674.1 examples/sec; 0.009 sec/batch)
# 15:04:29.507551: step 830, acc = 0.94 (5237.9 examples/sec; 0.010 sec/batch)
# 15:04:29.603260: step 840, acc = 0.98 (5603.5 examples/sec; 0.009 sec/batch)
# 15:04:29.702270: step 850, acc = 0.92 (5514.5 examples/sec; 0.009 sec/batch)
# 15:04:29.799453: step 860, acc = 0.98 (5396.0 examples/sec; 0.009 sec/batch)
# 15:04:29.905143: step 870, acc = 0.98 (4729.0 examples/sec; 0.011 sec/batch)
# 15:04:30.006027: step 880, acc = 0.94 (5348.8 examples/sec; 0.009 sec/batch)
# 15:04:30.112374: step 890, acc = 0.94 (4236.9 examples/sec; 0.012 sec/batch)
# 15:04:30.209148: step 900, acc = 0.94 (5534.0 examples/sec; 0.009 sec/batch)
# 15:04:30.581095: step 910, acc = 0.92 (5579.2 examples/sec; 0.009 sec/batch)
# 15:04:30.676964: step 920, acc = 0.96 (5383.2 examples/sec; 0.009 sec/batch)
# 15:04:30.770756: step 930, acc = 1.00 (5586.0 examples/sec; 0.009 sec/batch)
# 15:04:30.862995: step 940, acc = 1.00 (5822.0 examples/sec; 0.009 sec/batch)
# 15:04:30.952716: step 950, acc = 0.98 (5913.6 examples/sec; 0.008 sec/batch)
# 15:04:31.038491: step 960, acc = 1.00 (6022.0 examples/sec; 0.008 sec/batch)
# 15:04:31.128185: step 970, acc = 0.96 (5683.8 examples/sec; 0.009 sec/batch)
# 15:04:31.216365: step 980, acc = 0.96 (5953.8 examples/sec; 0.008 sec/batch)
# 15:04:31.303722: step 990, acc = 0.98 (5761.1 examples/sec; 0.009 sec/batch)
# 15:04:31.392048: step 1000, acc = 0.90 (5784.9 examples/sec; 0.009 sec/batch)
# 15:04:31.775054: step 1010, acc = 0.96 (5529.2 examples/sec; 0.009 sec/batch)
# 15:04:31.868099: step 1020, acc = 0.96 (5767.1 examples/sec; 0.009 sec/batch)
# 15:04:31.958841: step 1030, acc = 0.98 (5423.5 examples/sec; 0.009 sec/batch)
# 15:04:32.050346: step 1040, acc = 0.94 (5804.6 examples/sec; 0.009 sec/batch)
# 15:04:32.139782: step 1050, acc = 0.96 (5859.6 examples/sec; 0.009 sec/batch)
# 15:04:32.225462: step 1060, acc = 1.00 (6043.8 examples/sec; 0.008 sec/batch)
# 15:04:32.315324: step 1070, acc = 0.96 (5922.0 examples/sec; 0.008 sec/batch)
# 15:04:32.403920: step 1080, acc = 0.94 (5700.6 examples/sec; 0.009 sec/batch)
# 15:04:32.497805: step 1090, acc = 0.96 (5349.3 examples/sec; 0.009 sec/batch)
# 15:04:32.587587: step 1100, acc = 0.96 (5746.6 examples/sec; 0.009 sec/batch)
# 15:04:32.885531: step 1110, acc = 0.96 (5566.1 examples/sec; 0.009 sec/batch)
# 15:04:32.975560: step 1120, acc = 0.98 (5676.1 examples/sec; 0.009 sec/batch)
# 15:04:33.062976: step 1130, acc = 0.96 (5851.4 examples/sec; 0.009 sec/batch)
# 15:04:33.150096: step 1140, acc = 0.96 (6386.6 examples/sec; 0.008 sec/batch)
# 15:04:33.235082: step 1150, acc = 0.96 (5800.4 examples/sec; 0.009 sec/batch)
# 15:04:33.323629: step 1160, acc = 0.96 (6043.7 examples/sec; 0.008 sec/batch)
# 15:04:33.413936: step 1170, acc = 1.00 (5911.5 examples/sec; 0.008 sec/batch)
# 15:04:33.498287: step 1180, acc = 0.96 (6165.2 examples/sec; 0.008 sec/batch)
# 15:04:33.584224: step 1190, acc = 0.96 (6099.9 examples/sec; 0.008 sec/batch)
# 15:04:33.669028: step 1200, acc = 0.94 (6271.2 examples/sec; 0.008 sec/batch)
# 15:04:33.961795: step 1210, acc = 0.98 (6027.9 examples/sec; 0.008 sec/batch)
# 15:04:34.057912: step 1220, acc = 0.96 (5623.6 examples/sec; 0.009 sec/batch)
# 15:04:34.148717: step 1230, acc = 0.96 (6022.0 examples/sec; 0.008 sec/batch)
# 15:04:34.233789: step 1240, acc = 0.98 (6017.5 examples/sec; 0.008 sec/batch)
# 15:04:34.317879: step 1250, acc = 0.98 (5988.1 examples/sec; 0.008 sec/batch)
# 15:04:34.403270: step 1260, acc = 0.98 (6190.5 examples/sec; 0.008 sec/batch)
# 15:04:34.488545: step 1270, acc = 0.96 (6212.7 examples/sec; 0.008 sec/batch)
# 15:04:34.570871: step 1280, acc = 0.98 (6267.1 examples/sec; 0.008 sec/batch)
# 15:04:34.654339: step 1290, acc = 0.98 (6160.7 examples/sec; 0.008 sec/batch)
# 15:04:34.740312: step 1300, acc = 1.00 (5892.2 examples/sec; 0.008 sec/batch)
# 15:04:35.068544: step 1310, acc = 0.92 (5890.7 examples/sec; 0.008 sec/batch)
# 15:04:35.155806: step 1320, acc = 0.96 (6051.9 examples/sec; 0.008 sec/batch)
# 15:04:35.239687: step 1330, acc = 0.96 (6215.1 examples/sec; 0.008 sec/batch)
# 15:04:35.324303: step 1340, acc = 0.98 (6003.9 examples/sec; 0.008 sec/batch)
# 15:04:35.410734: step 1350, acc = 0.98 (6082.1 examples/sec; 0.008 sec/batch)
# 15:04:35.495680: step 1360, acc = 0.94 (6158.5 examples/sec; 0.008 sec/batch)
# 15:04:35.579709: step 1370, acc = 1.00 (6175.2 examples/sec; 0.008 sec/batch)
# 15:04:35.665153: step 1380, acc = 0.98 (5852.1 examples/sec; 0.009 sec/batch)
# 15:04:35.753369: step 1390, acc = 0.96 (6157.8 examples/sec; 0.008 sec/batch)
# 15:04:35.838015: step 1400, acc = 0.94 (5906.0 examples/sec; 0.008 sec/batch)
# 15:04:36.195313: step 1410, acc = 1.00 (5155.1 examples/sec; 0.010 sec/batch)
# 15:04:36.295229: step 1420, acc = 0.98 (5366.4 examples/sec; 0.009 sec/batch)
# 15:04:36.398245: step 1430, acc = 0.94 (4862.4 examples/sec; 0.010 sec/batch)
# 15:04:36.499425: step 1440, acc = 1.00 (5151.4 examples/sec; 0.010 sec/batch)
# 15:04:36.598207: step 1450, acc = 1.00 (5459.6 examples/sec; 0.009 sec/batch)
# 15:04:36.700943: step 1460, acc = 0.92 (5107.8 examples/sec; 0.010 sec/batch)
# 15:04:36.798210: step 1470, acc = 0.94 (5628.1 examples/sec; 0.009 sec/batch)
# 15:04:36.890723: step 1480, acc = 0.98 (5524.2 examples/sec; 0.009 sec/batch)
# 15:04:36.981071: step 1490, acc = 0.94 (5829.5 examples/sec; 0.009 sec/batch)
# 15:04:37.175880: step 1500, acc = 0.98 (453.1 examples/sec; 0.110 sec/batch)
# 15:04:37.516831: step 1510, acc = 0.90 (5805.7 examples/sec; 0.009 sec/batch)
# 15:04:37.609989: step 1520, acc = 0.98 (5559.2 examples/sec; 0.009 sec/batch)
# 15:04:37.701787: step 1530, acc = 0.98 (6125.2 examples/sec; 0.008 sec/batch)
# 15:04:37.787409: step 1540, acc = 0.98 (6004.6 examples/sec; 0.008 sec/batch)
# 15:04:37.876590: step 1550, acc = 0.96 (5808.6 examples/sec; 0.009 sec/batch)
# 15:04:37.964136: step 1560, acc = 0.98 (5908.6 examples/sec; 0.008 sec/batch)
# 15:04:38.053304: step 1570, acc = 1.00 (5901.2 examples/sec; 0.008 sec/batch)
# 15:04:38.148242: step 1580, acc = 0.98 (5919.1 examples/sec; 0.008 sec/batch)
# 15:04:38.234939: step 1590, acc = 0.98 (6070.1 examples/sec; 0.008 sec/batch)
# 15:04:38.321451: step 1600, acc = 0.96 (6080.5 examples/sec; 0.008 sec/batch)
# 15:04:38.720072: step 1610, acc = 0.94 (5685.0 examples/sec; 0.009 sec/batch)
# 15:04:38.813267: step 1620, acc = 0.98 (5647.8 examples/sec; 0.009 sec/batch)
# 15:04:38.903188: step 1630, acc = 0.98 (6084.9 examples/sec; 0.008 sec/batch)
# 15:04:38.988802: step 1640, acc = 0.98 (5965.1 examples/sec; 0.008 sec/batch)
# 15:04:39.072809: step 1650, acc = 0.98 (5059.2 examples/sec; 0.010 sec/batch)
# 15:04:39.155718: step 1660, acc = 0.98 (6561.6 examples/sec; 0.008 sec/batch)
# 15:04:39.235791: step 1670, acc = 0.96 (6306.7 examples/sec; 0.008 sec/batch)
# 15:04:39.319158: step 1680, acc = 0.94 (6318.8 examples/sec; 0.008 sec/batch)
# 15:04:39.399387: step 1690, acc = 0.94 (6425.1 examples/sec; 0.008 sec/batch)
# 15:04:39.481281: step 1700, acc = 0.96 (6303.6 examples/sec; 0.008 sec/batch)
# 15:04:39.761396: step 1710, acc = 1.00 (5876.8 examples/sec; 0.009 sec/batch)
# 15:04:39.849958: step 1720, acc = 0.94 (5647.8 examples/sec; 0.009 sec/batch)
# 15:04:39.940202: step 1730, acc = 0.94 (5881.0 examples/sec; 0.009 sec/batch)
# 15:04:40.034367: step 1740, acc = 0.96 (5434.9 examples/sec; 0.009 sec/batch)
# 15:04:40.124050: step 1750, acc = 1.00 (5913.6 examples/sec; 0.008 sec/batch)
# 15:04:40.206046: step 1760, acc = 1.00 (6422.7 examples/sec; 0.008 sec/batch)
# 15:04:40.284742: step 1770, acc = 0.94 (6523.0 examples/sec; 0.008 sec/batch)
# 15:04:40.363771: step 1780, acc = 0.96 (6379.2 examples/sec; 0.008 sec/batch)
# 15:04:40.446987: step 1790, acc = 0.98 (6402.9 examples/sec; 0.008 sec/batch)
# 15:04:40.534232: step 1800, acc = 1.00 (5415.9 examples/sec; 0.009 sec/batch)
# 15:04:40.899266: step 1810, acc = 0.96 (5672.1 examples/sec; 0.009 sec/batch)
# 15:04:40.987352: step 1820, acc = 1.00 (6035.0 examples/sec; 0.008 sec/batch)
# 15:04:41.075691: step 1830, acc = 1.00 (5815.2 examples/sec; 0.009 sec/batch)
# 15:04:41.163354: step 1840, acc = 0.96 (5931.9 examples/sec; 0.008 sec/batch)
# 15:04:41.249209: step 1850, acc = 0.94 (5928.3 examples/sec; 0.008 sec/batch)
# 15:04:41.339519: step 1860, acc = 1.00 (5013.0 examples/sec; 0.010 sec/batch)
# 15:04:41.435528: step 1870, acc = 0.98 (5357.3 examples/sec; 0.009 sec/batch)
# 15:04:41.526489: step 1880, acc = 0.96 (5631.9 examples/sec; 0.009 sec/batch)
# 15:04:41.621392: step 1890, acc = 1.00 (5880.3 examples/sec; 0.009 sec/batch)
# 15:04:41.710429: step 1900, acc = 0.98 (5997.3 examples/sec; 0.008 sec/batch)
# 15:04:42.123984: step 1910, acc = 0.92 (5613.1 examples/sec; 0.009 sec/batch)
# 15:04:42.212474: step 1920, acc = 0.98 (6232.8 examples/sec; 0.008 sec/batch)
# 15:04:42.297648: step 1930, acc = 0.98 (6153.1 examples/sec; 0.008 sec/batch)
# 15:04:42.385239: step 1940, acc = 1.00 (6154.5 examples/sec; 0.008 sec/batch)
# 15:04:42.470629: step 1950, acc = 1.00 (6006.6 examples/sec; 0.008 sec/batch)
# 15:04:42.557742: step 1960, acc = 0.96 (6234.5 examples/sec; 0.008 sec/batch)
# 15:04:42.644937: step 1970, acc = 0.98 (5771.1 examples/sec; 0.009 sec/batch)
# 15:04:42.738302: step 1980, acc = 1.00 (5757.1 examples/sec; 0.009 sec/batch)
# 15:04:42.826624: step 1990, acc = 1.00 (5871.9 examples/sec; 0.009 sec/batch)
# Test accuracy: 0.981
# DONE! All outputs have been written to: train
